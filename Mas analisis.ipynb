# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/Kevin Macario/Desktop/Uvg/9no Semestre/Mineria de Datos/ProyectoDataMining/defunciones_fetales/DefFet.csv", header = "infer", delimiter = ",", encoding = "latin-1")
data.head()
# Out:
#    DEPREG  MUPREG  MESREG  AÑOREG  DEPOCU  MUPOCU  AREAG  SEXO  DIAOCU  \
# 0       1     101      12    2017       1     101      9     1      14
# 1       1     114      11    2017       1     114      9     2       1
# 2      13    1301      11    2017      13    1301      9     1      24
# 3      14    1401      11    2017      14    1401      9     1      15
# 4      10    1001      11    2017      10    1001      9     1      21
#
#    MESOCU  ...  ESCOLAM  CIUOMAD  CAUDEF  ASISREC  SITIOOCU  TOHITE  TOHINM  \
# 0      12  ...        3     97.0    P000        1         9      99      99
# 1      11  ...        4     97.0    P000        1         9       2       1
# 2      10  ...        2     97.0    P000        5         9       2       1
# 3      11  ...        2     97.0    P000        1         9      99      99
# 4      11  ...        3     97.0    P000        1         9       3       1
#
#    TOHIVI  GRETNM  OCUPAM
# 0      99     NaN     NaN
# 1       1     NaN     NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34355 entries, 0 to 34354
# Data columns (total 32 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DEPREG    34355 non-null  int64
#  1   MUPREG    34355 non-null  int64
#  2   MESREG    34355 non-null  int64
#  3   AÑOREG    34355 non-null  int64
#  4   DEPOCU    34355 non-null  int64
#  5   MUPOCU    34355 non-null  int64
#  6   AREAG     34355 non-null  int64
#  7   SEXO      34355 non-null  int64
#  8   DIAOCU    34355 non-null  int64
#  9   MESOCU    34355 non-null  int64
#  10  AÑOOCU    9099 non-null   float64
#  11  TIPAR     34355 non-null  int64
#  12  CLAPAR    34355 non-null  int64
#  13  VIAPAR    34355 non-null  int64
#  14  SEMGES    34355 non-null  int64
#  15  EDADM     34355 non-null  int64
#  16  PAISREM   34355 non-null  int64
#  17  DEPREM    34355 non-null  int64
#  18  MUPREM    34355 non-null  int64
#  19  PUEBLOPM  9099 non-null   float64
# ...

# %%
data.drop('AÑOOCU', inplace=True, axis=1)

# %%
f, ax = plt.subplots(figsize=(23, 23))
sns.heatmap(data.corr(),annot=True, fmt=".2f", linewidths=.5, ax=ax)
plt.show()

# %%
len(data)
# Out:
# 34355
